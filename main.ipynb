# %% [markdown]
# # [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JoseHernandez11/k_brazos_JMHJDRJG/blob/main/main.ipynb)

# %% [markdown]
#  # 📌 Clonando el repositorio y configurando el entorno

# %%
# !git clone https://github.com/JoseHernandez11/k_brazos_JMHJDRJG.git
# %cd k_brazos_JMHJDRJG

# Instalación de paquetes necesarios (modifica según necesidad)
# !pip install -r requirements.txt || echo "No se encontró requirements.txt"

# %%
# Listar notebooks disponibles
import os
notebooks = [f for f in os.listdir() if f.endswith('.ipynb')]
print("\n📂 Notebooks disponibles en el repositorio:")
for nb in notebooks:
    print(f"- {nb}")

# %%
# Generar enlaces de navegación para los notebooks en el repo
from IPython.display import display, Markdown
import os

repo_url = "https://colab.research.google.com/github/JoseHernandez11/k_brazos_JMHJDRJG/blob/main/"
notebooks = [f for f in os.listdir() if f.endswith('.ipynb')]

md_links = "## 📂 Navegar entre Notebooks\n"
for nb in notebooks:
    md_links += f"- [{nb}]({repo_url}{nb})\n"

display(Markdown(md_links))
